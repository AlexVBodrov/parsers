# %% [markdown]
# Импортируем библиотки

# %%
# _ 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.
# https://api.github.com/users/USERNAME/repos

import requests
import time
import json
from pprint import pprint

USERNAME = 'AlexVBodrov'  # input('Введите username: ')


url = f'https://api.github.com/users/{USERNAME}/repos'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'}
response = requests.get(url)

data = response.json()

# src = response.text


# with open("exercise_2/index.html", "w") as file:
#     file.write(src)

    
print('Получен результат:')
pprint(data)

repo = []
for item in data:
    repo.append(item['name'])
print(f'Список репозиториев пользователя {USERNAME}')
pprint(repo)

# with open(f'exercise_2/{USERNAME}_repos.json', 'w') as f:
#     json_repo = json.dump(repo, f)
# Out:
# Получен результат:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/Basics_relational_databases_MySQL.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/contributors',
#   'created_at': '2021-05-24T07:37:23Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/deployments',
#   'description': 'Основы реляционных баз данных. MySQL',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/forks',
#   'full_name': 'AlexVBodrov/Basics_relational_databases_MySQL',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/Basics_relational_databases_MySQL.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/Basics_relational_databases_MySQL',
#   'id': 370267783,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/languages',
#   'license': {'key': 'gpl-3.0',
#               'name': 'GNU General Public License v3.0',
#               'node_id': 'MDc6TGljZW5zZTk=',
#               'spdx_id': 'GPL-3.0',
#               'url': 'https://api.github.com/licenses/gpl-3.0'},
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Basics_relational_databases_MySQL',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNzAyNjc3ODM=',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/notifications{?since,all,participating}',
#   'open_issues': 9,
#   'open_issues_count': 9,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/pulls{/number}',
#   'pushed_at': '2021-06-30T22:22:18Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/releases{/id}',
#   'size': 3067,
#   'ssh_url': 'git@github.com:AlexVBodrov/Basics_relational_databases_MySQL.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/Basics_relational_databases_MySQL',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL/git/trees{/sha}',
#   'updated_at': '2021-05-24T07:37:27Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/Basics_relational_databases_MySQL',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/chat_python.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/contributors',
#   'created_at': '2022-12-03T18:28:09Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/forks',
#   'full_name': 'AlexVBodrov/chat_python',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/chat_python.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/chat_python',
#   'id': 573884028,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/milestones{/number}',
#   'mirror_url': None,
#   'name': 'chat_python',
#   'node_id': 'R_kgDOIjTGfA',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/notifications{?since,all,participating}',
#   'open_issues': 2,
#   'open_issues_count': 2,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/pulls{/number}',
#   'pushed_at': '2023-01-25T23:11:57Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/releases{/id}',
#   'size': 1581,
#   'ssh_url': 'git@github.com:AlexVBodrov/chat_python.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/chat_python',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/chat_python/git/trees{/sha}',
#   'updated_at': '2022-12-05T17:48:00Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/chat_python',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/db_age/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/db_age/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/db_age/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/db_age/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/db_age.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/db_age/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/db_age/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/db_age/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/db_age/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/db_age/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/db_age/contributors',
#   'created_at': '2023-06-16T11:57:22Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/db_age/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/db_age/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/db_age/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/db_age/forks',
#   'full_name': 'AlexVBodrov/db_age',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/db_age/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/db_age/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/db_age/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/db_age.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/db_age/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/db_age',
#   'id': 654562318,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/db_age/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/db_age/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/db_age/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/db_age/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/db_age/labels{/name}',
#   'language': 'CSS',
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/db_age/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/db_age/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/db_age/milestones{/number}',
#   'mirror_url': None,
#   'name': 'db_age',
#   'node_id': 'R_kgDOJwPUDg',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/db_age/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/db_age/pulls{/number}',
#   'pushed_at': '2023-08-21T15:42:57Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/db_age/releases{/id}',
#   'size': 6579,
#   'ssh_url': 'git@github.com:AlexVBodrov/db_age.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/db_age/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/db_age/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/db_age/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/db_age/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/db_age',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/db_age/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/db_age/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/db_age/git/trees{/sha}',
#   'updated_at': '2023-08-11T20:30:47Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/db_age',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/DB_project_Ekatalog_m.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/contributors',
#   'created_at': '2021-07-14T11:39:56Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/forks',
#   'full_name': 'AlexVBodrov/DB_project_Ekatalog_m',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/DB_project_Ekatalog_m.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/DB_project_Ekatalog_m',
#   'id': 385918971,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/milestones{/number}',
#   'mirror_url': None,
#   'name': 'DB_project_Ekatalog_m',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzODU5MTg5NzE=',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/pulls{/number}',
#   'pushed_at': '2021-07-14T11:44:20Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/releases{/id}',
#   'size': 210,
#   'ssh_url': 'git@github.com:AlexVBodrov/DB_project_Ekatalog_m.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/DB_project_Ekatalog_m',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m/git/trees{/sha}',
#   'updated_at': '2021-07-14T11:44:22Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/DB_project_Ekatalog_m',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/Django_3_tools_optimisations.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/contributors',
#   'created_at': '2021-12-17T11:17:06Z',
#   'default_branch': 'lesson_1',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/forks',
#   'full_name': 'AlexVBodrov/Django_3_tools_optimisations',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/Django_3_tools_optimisations.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/Django_3_tools_optimisations',
#   'id': 439307062,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/labels{/name}',
#   'language': 'CSS',
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Django_3_tools_optimisations',
#   'node_id': 'R_kgDOGi9LNg',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/notifications{?since,all,participating}',
#   'open_issues': 1,
#   'open_issues_count': 1,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/pulls{/number}',
#   'pushed_at': '2021-12-17T11:25:55Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/releases{/id}',
#   'size': 1908,
#   'ssh_url': 'git@github.com:AlexVBodrov/Django_3_tools_optimisations.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/Django_3_tools_optimisations',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations/git/trees{/sha}',
#   'updated_at': '2022-05-26T14:38:26Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/Django_3_tools_optimisations',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/django_base/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/django_base/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/django_base/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/django_base/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/django_base.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/django_base/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/django_base/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/django_base/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/django_base/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/django_base/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/django_base/contributors',
#   'created_at': '2021-10-10T05:24:00Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/django_base/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/django_base/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/django_base/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/django_base/forks',
#   'full_name': 'AlexVBodrov/django_base',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/django_base/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/django_base/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/django_base/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/django_base.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/django_base/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/django_base',
#   'id': 415493993,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/django_base/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/django_base/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/django_base/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/django_base/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/django_base/labels{/name}',
#   'language': 'CSS',
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/django_base/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/django_base/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/django_base/milestones{/number}',
#   'mirror_url': None,
#   'name': 'django_base',
#   'node_id': 'R_kgDOGMPvaQ',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/django_base/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/django_base/pulls{/number}',
#   'pushed_at': '2021-11-07T16:55:19Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/django_base/releases{/id}',
#   'size': 9902,
#   'ssh_url': 'git@github.com:AlexVBodrov/django_base.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/django_base/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/django_base/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/django_base/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/django_base/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/django_base',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/django_base/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/django_base/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/django_base/git/trees{/sha}',
#   'updated_at': '2021-11-07T16:55:14Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/django_base',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/Django_Framework_optimization.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/contributors',
#   'created_at': '2022-01-27T22:29:26Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/deployments',
#   'description': 'Django_Framework_optimization',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/forks',
#   'full_name': 'AlexVBodrov/Django_Framework_optimization',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/Django_Framework_optimization.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/Django_Framework_optimization',
#   'id': 452865815,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Django_Framework_optimization',
#   'node_id': 'R_kgDOGv4vFw',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/notifications{?since,all,participating}',
#   'open_issues': 1,
#   'open_issues_count': 1,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/pulls{/number}',
#   'pushed_at': '2022-05-26T14:50:20Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/releases{/id}',
#   'size': 8088,
#   'ssh_url': 'git@github.com:AlexVBodrov/Django_Framework_optimization.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/Django_Framework_optimization',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization/git/trees{/sha}',
#   'updated_at': '2022-02-21T20:09:13Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/Django_Framework_optimization',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/Django_REST_todo.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/contributors',
#   'created_at': '2022-02-25T19:27:55Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/forks',
#   'full_name': 'AlexVBodrov/Django_REST_todo',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/Django_REST_todo.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/Django_REST_todo',
#   'id': 463652293,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Django_REST_todo',
#   'node_id': 'R_kgDOG6LFxQ',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/pulls{/number}',
#   'pushed_at': '2022-02-25T19:27:56Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/releases{/id}',
#   'size': 0,
#   'ssh_url': 'git@github.com:AlexVBodrov/Django_REST_todo.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/Django_REST_todo/subscribers',
# ...
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/qt_dev_simple.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/qt_dev_simple',
#   'id': 578741755,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/milestones{/number}',
#   'mirror_url': None,
#   'name': 'qt_dev_simple',
#   'node_id': 'R_kgDOIn7l-w',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/pulls{/number}',
#   'pushed_at': '2023-01-18T14:28:52Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/releases{/id}',
#   'size': 38,
#   'ssh_url': 'git@github.com:AlexVBodrov/qt_dev_simple.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/qt_dev_simple',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple/git/trees{/sha}',
#   'updated_at': '2022-12-15T19:20:50Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/qt_dev_simple',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/typing_tr.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/contributors',
#   'created_at': '2021-05-29T13:54:27Z',
#   'default_branch': '1_branch',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/deployments',
#   'description': 'typing_trainer',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/forks',
#   'full_name': 'AlexVBodrov/typing_tr',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/typing_tr.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/typing_tr',
#   'id': 371985897,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/milestones{/number}',
#   'mirror_url': None,
#   'name': 'typing_tr',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNzE5ODU4OTc=',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/pulls{/number}',
#   'pushed_at': '2022-05-26T14:34:32Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/releases{/id}',
#   'size': 1245,
#   'ssh_url': 'git@github.com:AlexVBodrov/typing_tr.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/typing_tr',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/typing_tr/git/trees{/sha}',
#   'updated_at': '2022-05-26T14:34:20Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/typing_tr',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/branches{/branch}',
#   'clone_url': 'https://github.com/AlexVBodrov/typing_trainer.git',
#   'collaborators_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/contributors',
#   'created_at': '2021-05-17T14:00:04Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/deployments',
#   'description': 'typing_trainer',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/downloads',
#   'events_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/forks',
#   'full_name': 'AlexVBodrov/typing_trainer',
#   'git_commits_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/git/tags{/sha}',
#   'git_url': 'git://github.com/AlexVBodrov/typing_trainer.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/hooks',
#   'html_url': 'https://github.com/AlexVBodrov/typing_trainer',
#   'id': 368205994,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/merges',
#   'milestones_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/milestones{/number}',
#   'mirror_url': None,
#   'name': 'typing_trainer',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjgyMDU5OTQ=',
#   'notifications_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/77302302?v=4',
#             'events_url': 'https://api.github.com/users/AlexVBodrov/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/AlexVBodrov/followers',
#             'following_url': 'https://api.github.com/users/AlexVBodrov/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/AlexVBodrov/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/AlexVBodrov',
#             'id': 77302302,
#             'login': 'AlexVBodrov',
#             'node_id': 'MDQ6VXNlcjc3MzAyMzAy',
#             'organizations_url': 'https://api.github.com/users/AlexVBodrov/orgs',
#             'received_events_url': 'https://api.github.com/users/AlexVBodrov/received_events',
#             'repos_url': 'https://api.github.com/users/AlexVBodrov/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/AlexVBodrov/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/AlexVBodrov/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/AlexVBodrov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/pulls{/number}',
#   'pushed_at': '2021-07-26T06:23:45Z',
#   'releases_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/releases{/id}',
#   'size': 1239,
#   'ssh_url': 'git@github.com:AlexVBodrov/typing_trainer.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/stargazers',
#   'statuses_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/subscription',
#   'svn_url': 'https://github.com/AlexVBodrov/typing_trainer',
#   'tags_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/tags',
#   'teams_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer/git/trees{/sha}',
#   'updated_at': '2021-05-17T14:00:08Z',
#   'url': 'https://api.github.com/repos/AlexVBodrov/typing_trainer',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False}]
# Список репозиториев пользователя AlexVBodrov
# ['Basics_relational_databases_MySQL',
#  'chat_python',
#  'db_age',
#  'DB_project_Ekatalog_m',
#  'Django_3_tools_optimisations',
#  'django_base',
#  'Django_Framework_optimization',
#  'Django_REST_todo',
#  'drf_todo',
#  'gb_framework',
#  'javaScript_base',
#  'my_portfolio_project',
#  'parsers',
#  'python_algorithms',
#  'pyton_base',
#  'qt_dev_simple',
#  'typing_tr',
#  'typing_trainer']
